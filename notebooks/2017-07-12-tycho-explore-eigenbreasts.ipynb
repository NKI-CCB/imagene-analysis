# %%
import bqplot
from IPython.display import display
import ipywidgets
import numpy as np
import pandas as pd
import xarray as xr

import plot

# %%
eigenbreasts = xr.open_dataset('../data/processed/mri-eigenbreasts.nc')

# %%
for var in eigenbreasts.data_vars:
    plot.hist(eigenbreasts[var][0, :], title=var)

# %%
for var in eigenbreasts.data_vars:
    print(var)
    plot.scatter(eigenbreasts[var][0, :], eigenbreasts[var][1, :])
# Out:
# ipsi_ds2
# ipsi_ds4
# ipsi_ds8
# ipsi_ds16
# contra_ds2
# contra_ds4
# contra_ds8
# contra_ds16
# both_ds2
# both_ds4
# both_ds8
# both_ds16

# %%
outliers = dict()
for var in eigenbreasts.data_vars:
    val = eigenbreasts[var][0, :]
    outliers[var] = set(eigenbreasts['case'][val > 2*np.std(val.values)].values)
outliers
# Out:
# {'both_ds16': {217, 666, 793},
#  'both_ds2': {217, 666, 793},
#  'both_ds4': {217, 666, 793},
#  'both_ds8': {217, 666, 793},
#  'contra_ds16': {217, 666, 793},
#  'contra_ds2': {217, 666, 793},
#  'contra_ds4': {217, 666, 793},
#  'contra_ds8': {217, 666, 793},
#  'ipsi_ds16': {217, 666, 793},
#  'ipsi_ds2': {217, 666, 793},
#  'ipsi_ds4': {217, 666, 793},
#  'ipsi_ds8': {217, 666, 793}}

# %%
outliers = dict()
for var in eigenbreasts.data_vars:
    val = eigenbreasts[var][1, :]
    outliers[var] = set(eigenbreasts['case'][val > 2*np.std(val.values)].values)
outliers
# Out:
# {'both_ds16': {666},
#  'both_ds2': {666},
#  'both_ds4': {666},
#  'both_ds8': {666},
#  'contra_ds16': {666, 793},
#  'contra_ds2': {666},
#  'contra_ds4': {666},
#  'contra_ds8': {666},
#  'ipsi_ds16': {666},
#  'ipsi_ds2': {666},
#  'ipsi_ds4': {666},
#  'ipsi_ds8': {666}}

# %%
outliers = dict()
for var in eigenbreasts.data_vars:
    val = eigenbreasts[var][2, :]
    outliers[var] = set(eigenbreasts['case'][val > 2*np.std(val.values)].values)
outliers
# Out:
# {'both_ds16': {360, 666, 991, 1077, 1156, 1251, 1353, 1405, 1413, 1672},
#  'both_ds2': {793},
#  'both_ds4': {793},
#  'both_ds8': {793},
#  'contra_ds16': {666, 1077, 1405, 1413, 1484, 1672},
#  'contra_ds2': {793},
#  'contra_ds4': {793},
#  'contra_ds8': {666, 1077, 1156, 1251, 1353, 1405, 1413, 1672},
#  'ipsi_ds16': {360, 666, 877, 991, 1077, 1235, 1353, 1413},
#  'ipsi_ds2': {793},
#  'ipsi_ds4': {666, 793, 991, 1353},
#  'ipsi_ds8': {360, 666, 877, 907, 991, 1012, 1077, 1156, 1235, 1353, 1413}}

# %%
for var in eigenbreasts.data_vars:
    plot.hist(eigenbreasts[var][3, :], title=var)
